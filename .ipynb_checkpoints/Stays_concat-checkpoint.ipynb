# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict

import pickle

# %%
airports = pd.read_csv('Data/US_airports_geo.csv')

# %%
hosts = pd.read_csv('Data/AB_US_2020.csv', low_memory=False)

# %%
airports.head()
# Out:
#   IATA                              AIRPORT           CITY STATE COUNTRY  \
# 0  ABQ            Albuquerque International    Albuquerque    NM     USA
# 1  ANC  Ted Stevens Anchorage International      Anchorage    AK     USA
# 2  ATL    William B Hartsfield-Atlanta Intl        Atlanta    GA     USA
# 3  AUS       Austin-Bergstrom International         Austin    TX     USA
# 4  BDL                Bradley International  Windsor Locks    CT     USA
#
#     LATITUDE   LONGITUDE category
# 0  35.040222 -106.609194  Airport
# 1  61.174320 -149.996186  Airport
# 2  33.640444  -84.426944  Airport
# 3  30.194533  -97.669872  Airport
# 4  41.938874  -72.683228  Airport

# %%
hosts.drop(['host_id', 'host_name', 'neighbourhood_group', 'number_of_reviews', 'last_review','reviews_per_month','calculated_host_listings_count'], inplace=True, axis=1)

# %%
hosts.head()
# Out:
#        id                                               name neighbourhood  \
# 0   38585    Charming Victorian home - twin beds + breakfast         28804
# 1   80905                                   French Chic Loft         28801
# 2  108061  Walk to stores/parks/downtown. Fenced yard/Pet...         28801
# 3  155305                 Cottage! BonPaul + Sharky's Hostel         28806
# 4  160594                                Historic Grove Park         28801
#
#    latitude  longitude        room_type  price  minimum_nights  \
# 0  35.65146  -82.62792     Private room     60               1
# 1  35.59779  -82.55540  Entire home/apt    470               1
# 2  35.60670  -82.55563  Entire home/apt     75              30
# 3  35.57864  -82.59578  Entire home/apt     90               1
# 4  35.61442  -82.54127     Private room    125              30
#
#    availability_365       city category
# 0                 0  Asheville     Home
# 1               288  Asheville     Home
# 2               298  Asheville     Home
# 3                 0  Asheville     Home
# 4                 0  Asheville     Home

# %%
airports['category'] = 'Airport'
airports.columns = airports.columns.str.lower()
hosts['category'] = 'Home'

# %%
mushed = pd.concat([airports, hosts], ignore_index=True)

# %% [markdown]
# ### Try K-means, they are distance based.

# %%
from sklearn.cluster import KMeans

# %%
X_c = mushed[['latitude','longitude']]

# %%
K = range(21, 43)
inertia = []

for k in K:
#     print("Training a K-Means model with {} clusters! ".format(k))
#     print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_c)
    inertia.append(kmeans.inertia_)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
clusters = KMeans(n_clusters=37, random_state=0).fit(X_c)

# %%
mushed['Labels'] = clusters.labels_

# %%
mush_impd.to_csv('Data/Outputs/mushed.csv')

# %%
mushed.head()
# Out:
#   iata                              airport           city state country  \
# 0  ABQ            Albuquerque International    Albuquerque    NM     USA
# 1  ANC  Ted Stevens Anchorage International      Anchorage    AK     USA
# 2  ATL    William B Hartsfield-Atlanta Intl        Atlanta    GA     USA
# 3  AUS       Austin-Bergstrom International         Austin    TX     USA
# 4  BDL                Bradley International  Windsor Locks    CT     USA
#
#     latitude   longitude category  id name neighbourhood room_type  price  \
# 0  35.040222 -106.609194  Airport NaN  NaN           NaN       NaN    NaN
# 1  61.174320 -149.996186  Airport NaN  NaN           NaN       NaN    NaN
# 2  33.640444  -84.426944  Airport NaN  NaN           NaN       NaN    NaN
# 3  30.194533  -97.669872  Airport NaN  NaN           NaN       NaN    NaN
# 4  41.938874  -72.683228  Airport NaN  NaN           NaN       NaN    NaN
#
#    minimum_nights  availability_365  Labels
# 0             NaN               NaN       7
# 1             NaN               NaN      33
# 2             NaN               NaN      16
# 3             NaN               NaN       6
# 4             NaN               NaN      25

# %%
from sklearn.impute import SimpleImputer

# %%
imp = SimpleImputer(missing_values=np.nan, strategy="most_frequent")
imp.fit(mushed)
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
mush_impd = pd.DataFrame(imp.transform(mushed), columns=mushed.columns)

# %%
mush_impd['price'] = mush_impd['price'].astype(np.int64)

# %%
e =[mush_impd[['price','Labels']].groupby(['Labels']).quantile(0.25)['price'][i] for i in range(37)]
q = {i:j for i,j in zip(range(1,38), e)}

# %%
mush_impd.loc[mush_impd['Labels']==36]
# Out:
#       iata            airport     city state country  latitude   longitude  \
# 44     OGG            Kahului  Kahului    HI     USA  20.89865 -156.430458
# 48497  ABE  Aberdeen Regional   Hawaii    CA     USA   20.7547  -156.45666
# 48503  ABE  Aberdeen Regional   Hawaii    CA     USA  20.72475  -156.44926
# 48506  ABE  Aberdeen Regional   Hawaii    CA     USA  20.75874   -156.4567
# 48525  ABE  Aberdeen Regional   Hawaii    CA     USA   20.7191  -156.44511
# ...    ...                ...      ...   ...     ...       ...         ...
# 70901  ABE  Aberdeen Regional   Hawaii    CA     USA  20.71176  -156.44338
# 70902  ABE  Aberdeen Regional   Hawaii    CA     USA  20.75961  -156.45727
# 70903  ABE  Aberdeen Regional   Hawaii    CA     USA   20.7705  -156.45917
# 70909  ABE  Aberdeen Regional   Hawaii    CA     USA  20.70807  -156.44545
# 70912  ABE  Aberdeen Regional   Hawaii    CA     USA  20.72228  -156.44685
#
#       category          id                                               name  \
# 44     Airport  43806155.0                                Home away from home
# 48497     Home      7896.0                       Beachfront Maui Sunset Condo
# 48503     Home     13528.0                    2BR Pacific Shores by the Beach
# 48506     Home     13799.0                Luana Kai Oceanfront Condo by Owner
# 48525     Home     24500.0  Great 1 Bdrm Across fr Beach OceanView! Start ...
# ...        ...         ...                                                ...
# 70901     Home  45455660.0        My Perfect Stays: New Listing Special $179!
# 70902     Home  45455745.0        Love Shack Suite overlooking Maalaea Harbor
# 70903     Home  45457247.0                           Maui Beach Vacation Club
# 70909     Home  45463860.0                           Maui Lea at Maui Hill #3
# 70912     Home  45463953.0                              Kamaole Beach Club #2
#
#               neighbourhood        room_type  price minimum_nights  \
# 44     Unincorporated Areas  Entire home/apt    100            1.0
# 48497          Kihei-Makena  Entire home/apt    120            4.0
# 48503          Kihei-Makena  Entire home/apt    135            2.0
# 48506          Kihei-Makena  Entire home/apt    129            2.0
# 48525          Kihei-Makena  Entire home/apt    149            2.0
# ...                     ...              ...    ...            ...
# 70901          Kihei-Makena  Entire home/apt    179            1.0
# 70902          Kihei-Makena  Entire home/apt    125            1.0
# 70903          Kihei-Makena     Private room    300            4.0
# 70909          Kihei-Makena  Entire home/apt    499            1.0
# 70912          Kihei-Makena  Entire home/apt    499            1.0
#
#       availability_365 Labels  q_price
# 44                 0.0     36     72.0
# 48497            344.0     36     72.0
# 48503            308.0     36     72.0
# 48506            239.0     36     72.0
# 48525            164.0     36     72.0
# ...                ...    ...      ...
# 70901            302.0     36     72.0
# 70902            242.0     36     72.0
# 70903            251.0     36     72.0
# 70909              7.0     36     72.0
# 70912             14.0     36     72.0
#
# [4293 rows x 17 columns]

# %%
mush_impd['q_price'].loc[mush_impd['Labels']==24]
# Out:
# 164       90.0
# 257       90.0
# 301       90.0
# 166456    90.0
# 166457    90.0
#           ...
# 205971    90.0
# 205972    90.0
# 205973    90.0
# 205974    90.0
# 205975    90.0
# Name: q_price, Length: 1857, dtype: float64

# %%
for key,val in q.items():
    mush_impd['q_price'].loc[mush_impd['Labels']==key] = val
# Out:
# /var/folders/gh/lf0mc7p936xfvjr53gs0s95m0000gn/T/ipykernel_8157/704664532.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mush_impd['q_price'].loc[mush_impd['Labels']==key] = val

# %%
with open('Files/nn_airports','wb') as file:
    pickle.dump(clusters, file)
